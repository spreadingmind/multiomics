# %%
import h5py
from mofapy2.run.entry_point import entry_point
import pandas as pd

# %%
file = "ftp://ftp.ebi.ac.uk/pub/databases/mofa/getting_started/data.txt.gz"
data = pd.read_csv(file, sep="\t")

data
# Out:
#                    sample    group             feature    view  value
# 0        sample_0_group_0  group_0    feature_0_view_0  view_0  -2.05
# 1        sample_1_group_0  group_0    feature_0_view_0  view_0   0.10
# 2        sample_2_group_0  group_0    feature_0_view_0  view_0   1.44
# 3        sample_3_group_0  group_0    feature_0_view_0  view_0  -0.28
# 4        sample_4_group_0  group_0    feature_0_view_0  view_0  -0.88
# ...                   ...      ...                 ...     ...    ...
# 399995  sample_95_group_1  group_1  feature_999_view_1  view_1   0.21
# 399996  sample_96_group_1  group_1  feature_999_view_1  view_1   0.47
# 399997  sample_97_group_1  group_1  feature_999_view_1  view_1   0.49
# 399998  sample_98_group_1  group_1  feature_999_view_1  view_1   0.19
# 399999  sample_99_group_1  group_1  feature_999_view_1  view_1  -1.60
#
# [400000 rows x 5 columns]

# %%
data
# Out:
#                    sample    group             feature    view  value
# 0        sample_0_group_0  group_0    feature_0_view_0  view_0  -2.05
# 1        sample_1_group_0  group_0    feature_0_view_0  view_0   0.10
# 2        sample_2_group_0  group_0    feature_0_view_0  view_0   1.44
# 3        sample_3_group_0  group_0    feature_0_view_0  view_0  -0.28
# 4        sample_4_group_0  group_0    feature_0_view_0  view_0  -0.88
# ...                   ...      ...                 ...     ...    ...
# 399995  sample_95_group_1  group_1  feature_999_view_1  view_1   0.21
# 399996  sample_96_group_1  group_1  feature_999_view_1  view_1   0.47
# 399997  sample_97_group_1  group_1  feature_999_view_1  view_1   0.49
# 399998  sample_98_group_1  group_1  feature_999_view_1  view_1   0.19
# 399999  sample_99_group_1  group_1  feature_999_view_1  view_1  -1.60
#
# [400000 rows x 5 columns]

# %%
ent = entry_point()


# (2) Set data options
# - scale_views: if views have very different ranges, one can to scale each view to unit variance
ent.set_data_options(
    scale_views=False
)

# (3) Set data using the data frame format
ent.set_data_df(data.drop('group', axis=1))

# using default values
ent.set_model_options()

# using personalised values
ent.set_model_options(
    factors=5,
    spikeslab_weights=True,
    ard_weights=True
)

## (5) Set training options ##
# - iter: number of iterations
# - convergence_mode: "fast", "medium", "slow". Fast mode is usually good enough.
# - dropR2: minimum variance explained criteria to drop factors while training. Default is None, inactive factors are not dropped during training
# - gpu_mode: use GPU mode? this functionality needs cupy installed and a functional GPU, see https://biofam.github.io/MOFA2/gpu_training.html
# - seed: random seed

# using default values
ent.set_train_options()

# using personalised values
ent.set_train_options(
    iter=100,
    convergence_mode="fast",
    dropR2=None,
    gpu_mode=False,
    seed=42
)

####################################
## Build and train the MOFA model ##
####################################

# Build the model
ent.build()

# Run the model
ent.run()

####################
## Save the model ##
####################

outfile = "template_test.hdf5"

# - save_data: logical indicating whether to save the training data in the hdf5 file.
# this is useful for some downstream analysis in R, but it can take a lot of disk space.
ent.save(outfile, save_data=True)

#########################
## Downstream analysis ##
#########################

# Check the mofax package for the downstream analysis in Python: https://github.com/bioFAM/mofax
# Check the MOFA2 R package for the downstream analysis in R: https://www.bioconductor.org/packages/release/bioc/html/MOFA2.html
# All tutorials: https://biofam.github.io/MOFA2/tutorials.html

# Extract factor values (a list with one matrix per sample group)
factors = ent.model.nodes["Z"].getExpectation()

# Extract weights  (a list with one matrix per view)
weights = ent.model.nodes["W"].getExpectation()

# Extract variance explained values
r2 = ent.model.calculate_variance_explained()

# Interact directly with the hdf5 file
f = h5py.File(outfile, 'r')
f.keys()
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
#
# No "group" column found in the data frame, we will assume a common group for all samples...
#
#
# Loaded group='single_group' view='view_0' with N=200 samples and D=1000 features...
# Loaded group='single_group' view='view_1' with N=200 samples and D=1000 features...
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (view_0): gaussian
# - View 1 (view_1): gaussian
#
#
# Model options:
# - Automatic Relevance Determination prior on the factors: False
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (view_0): gaussian
# - View 1 (view_1): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 42 ##
# ######################################
#
#
# ELBO before training: -2011856.63
#
# Iteration 1: time=0.03, ELBO=-547941.80, deltaELBO=1463914.825 (72.76437119%), Factors=5
# Iteration 2: time=0.02, ELBO=-465219.20, deltaELBO=82722.600 (4.11175422%), Factors=5
# Iteration 3: time=0.02, ELBO=-459959.31, deltaELBO=5259.898 (0.26144499%), Factors=5
# Iteration 4: time=0.02, ELBO=-457763.21, deltaELBO=2196.092 (0.10915746%), Factors=5
# Iteration 5: time=0.02, ELBO=-456840.66, deltaELBO=922.558 (0.04585608%), Factors=5
# Iteration 6: time=0.02, ELBO=-456484.36, deltaELBO=356.299 (0.01770997%), Factors=5
# Iteration 7: time=0.02, ELBO=-456315.76, deltaELBO=168.592 (0.00837993%), Factors=5
# Iteration 8: time=0.02, ELBO=-456206.45, deltaELBO=109.317 (0.00543362%), Factors=5
# Iteration 9: time=0.02, ELBO=-456117.74, deltaELBO=88.710 (0.00440937%), Factors=5
# Iteration 10: time=0.02, ELBO=-456037.94, deltaELBO=79.802 (0.00396656%), Factors=5
# Iteration 11: time=0.02, ELBO=-455963.16, deltaELBO=74.775 (0.00371673%), Factors=5
# Iteration 12: time=0.02, ELBO=-455892.00, deltaELBO=71.163 (0.00353718%), Factors=5
# Iteration 13: time=0.02, ELBO=-455823.86, deltaELBO=68.139 (0.00338686%), Factors=5
# Iteration 14: time=0.02, ELBO=-455758.37, deltaELBO=65.485 (0.00325493%), Factors=5
# Iteration 15: time=0.02, ELBO=-455695.20, deltaELBO=63.176 (0.00314020%), Factors=5
# Iteration 16: time=0.02, ELBO=-455634.01, deltaELBO=61.188 (0.00304138%), Factors=5
# Iteration 17: time=0.02, ELBO=-455574.56, deltaELBO=59.447 (0.00295483%), Factors=5
# Iteration 18: time=0.02, ELBO=-455516.71, deltaELBO=57.857 (0.00287579%), Factors=5
# Iteration 19: time=0.02, ELBO=-455460.36, deltaELBO=56.347 (0.00280074%), Factors=5
# Iteration 20: time=0.02, ELBO=-455405.46, deltaELBO=54.901 (0.00272889%), Factors=5
# Iteration 21: time=0.02, ELBO=-455351.90, deltaELBO=53.555 (0.00266198%), Factors=5
# Iteration 22: time=0.02, ELBO=-455299.54, deltaELBO=52.361 (0.00260265%), Factors=5
# Iteration 23: time=0.02, ELBO=-455248.21, deltaELBO=51.330 (0.00255137%), Factors=5
# Iteration 24: time=0.02, ELBO=-455197.80, deltaELBO=50.413 (0.00250578%), Factors=5
# Iteration 25: time=0.02, ELBO=-455148.22, deltaELBO=49.581 (0.00246443%), Factors=5
# Iteration 26: time=0.02, ELBO=-455099.34, deltaELBO=48.877 (0.00242946%), Factors=5
# Iteration 27: time=0.02, ELBO=-455050.94, deltaELBO=48.397 (0.00240557%), Factors=5
# Iteration 28: time=0.02, ELBO=-455002.69, deltaELBO=48.256 (0.00239858%), Factors=5
# Iteration 29: time=0.02, ELBO=-454954.10, deltaELBO=48.586 (0.00241500%), Factors=5
# Iteration 30: time=0.02, ELBO=-454904.58, deltaELBO=49.519 (0.00246133%), Factors=5
# Iteration 31: time=0.02, ELBO=-454853.47, deltaELBO=51.117 (0.00254077%), Factors=5
# Iteration 32: time=0.02, ELBO=-454800.18, deltaELBO=53.286 (0.00264861%), Factors=5
# Iteration 33: time=0.02, ELBO=-454744.40, deltaELBO=55.779 (0.00277252%), Factors=5
# Iteration 34: time=0.02, ELBO=-454686.11, deltaELBO=58.292 (0.00289744%), Factors=5
# Iteration 35: time=0.02, ELBO=-454625.48, deltaELBO=60.629 (0.00301358%), Factors=5
# Iteration 36: time=0.02, ELBO=-454562.61, deltaELBO=62.872 (0.00312507%), Factors=5
# Iteration 37: time=0.02, ELBO=-454497.36, deltaELBO=65.247 (0.00324314%), Factors=5
# Iteration 38: time=0.02, ELBO=-454429.85, deltaELBO=67.511 (0.00335567%), Factors=5
# Iteration 39: time=0.02, ELBO=-454360.41, deltaELBO=69.434 (0.00345123%), Factors=5
# Iteration 40: time=0.02, ELBO=-454289.06, deltaELBO=71.353 (0.00354663%), Factors=5
# Iteration 41: time=0.02, ELBO=-454215.74, deltaELBO=73.326 (0.00364469%), Factors=5
# Iteration 42: time=0.02, ELBO=-454140.68, deltaELBO=75.061 (0.00373092%), Factors=5
# Iteration 43: time=0.02, ELBO=-454063.94, deltaELBO=76.739 (0.00381436%), Factors=5
# Iteration 44: time=0.02, ELBO=-453985.01, deltaELBO=78.923 (0.00392291%), Factors=5
# Iteration 45: time=0.02, ELBO=-453904.13, deltaELBO=80.882 (0.00402028%), Factors=5
# Iteration 46: time=0.02, ELBO=-453824.24, deltaELBO=79.894 (0.00397114%), Factors=5
# Iteration 47: time=0.02, ELBO=-453751.38, deltaELBO=72.851 (0.00362110%), Factors=5
# Iteration 48: time=0.02, ELBO=-453689.12, deltaELBO=62.265 (0.00309491%), Factors=5
# Iteration 49: time=0.02, ELBO=-453635.95, deltaELBO=53.170 (0.00264285%), Factors=5
# Iteration 50: time=0.02, ELBO=-449434.29, deltaELBO=4201.664 (0.20884511%), Factors=5
# Iteration 51: time=0.02, ELBO=-449090.24, deltaELBO=344.042 (0.01710070%), Factors=5
# Iteration 52: time=0.02, ELBO=-448982.15, deltaELBO=108.089 (0.00537262%), Factors=5
# Iteration 53: time=0.02, ELBO=-448930.45, deltaELBO=51.706 (0.00257007%), Factors=5
# Iteration 54: time=0.02, ELBO=-448897.35, deltaELBO=33.096 (0.00164503%), Factors=5
# Iteration 55: time=0.02, ELBO=-448871.10, deltaELBO=26.248 (0.00130466%), Factors=5
# Iteration 56: time=0.02, ELBO=-448847.75, deltaELBO=23.352 (0.00116073%), Factors=5
# Iteration 57: time=0.02, ELBO=-448825.85, deltaELBO=21.899 (0.00108852%), Factors=5
# Iteration 58: time=0.02, ELBO=-448804.83, deltaELBO=21.021 (0.00104487%), Factors=5
# Iteration 59: time=0.02, ELBO=-448784.44, deltaELBO=20.393 (0.00101362%), Factors=5
# Iteration 60: time=0.02, ELBO=-448764.56, deltaELBO=19.883 (0.00098828%), Factors=5
# Iteration 61: time=0.02, ELBO=-448745.12, deltaELBO=19.437 (0.00096611%), Factors=5
# Iteration 62: time=0.02, ELBO=-448726.09, deltaELBO=19.031 (0.00094592%), Factors=5
# Iteration 63: time=0.04, ELBO=-448707.44, deltaELBO=18.653 (0.00092715%), Factors=5
# Iteration 64: time=0.03, ELBO=-448689.14, deltaELBO=18.298 (0.00090952%), Factors=5
# Iteration 65: time=0.02, ELBO=-448671.17, deltaELBO=17.964 (0.00089289%), Factors=5
# Iteration 66: time=0.02, ELBO=-448653.53, deltaELBO=17.648 (0.00087719%), Factors=5
# Iteration 67: time=0.02, ELBO=-448636.18, deltaELBO=17.349 (0.00086236%), Factors=5
# Iteration 68: time=0.02, ELBO=-448619.11, deltaELBO=17.068 (0.00084835%), Factors=5
# Iteration 69: time=0.02, ELBO=-448602.31, deltaELBO=16.802 (0.00083515%), Factors=5
# Iteration 70: time=0.02, ELBO=-448585.76, deltaELBO=16.552 (0.00082271%), Factors=5
# Iteration 71: time=0.02, ELBO=-448569.44, deltaELBO=16.316 (0.00081102%), Factors=5
# Iteration 72: time=0.02, ELBO=-448553.34, deltaELBO=16.096 (0.00080004%), Factors=5
# Iteration 73: time=0.02, ELBO=-448537.45, deltaELBO=15.889 (0.00078977%), Factors=5
# Iteration 74: time=0.02, ELBO=-448521.76, deltaELBO=15.696 (0.00078016%), Factors=5
# Iteration 75: time=0.02, ELBO=-448506.24, deltaELBO=15.515 (0.00077119%), Factors=5
# Iteration 76: time=0.02, ELBO=-448490.90, deltaELBO=15.347 (0.00076283%), Factors=5
# Iteration 77: time=0.02, ELBO=-448475.71, deltaELBO=15.190 (0.00075502%), Factors=5
# Iteration 78: time=0.02, ELBO=-448460.66, deltaELBO=15.043 (0.00074772%), Factors=5
# Iteration 79: time=0.02, ELBO=-448445.76, deltaELBO=14.905 (0.00074085%), Factors=5
# Iteration 80: time=0.02, ELBO=-448430.98, deltaELBO=14.773 (0.00073432%), Factors=5
# Iteration 81: time=0.02, ELBO=-448416.34, deltaELBO=14.646 (0.00072799%), Factors=5
# Iteration 82: time=0.02, ELBO=-448401.82, deltaELBO=14.520 (0.00072174%), Factors=5
# Iteration 83: time=0.02, ELBO=-448387.43, deltaELBO=14.392 (0.00071537%), Factors=5
# Iteration 84: time=0.02, ELBO=-448373.17, deltaELBO=14.259 (0.00070874%), Factors=5
# Iteration 85: time=0.02, ELBO=-448359.05, deltaELBO=14.117 (0.00070168%), Factors=5
# Iteration 86: time=0.02, ELBO=-448345.09, deltaELBO=13.964 (0.00069407%), Factors=5
# Iteration 87: time=0.02, ELBO=-448331.29, deltaELBO=13.798 (0.00068586%), Factors=5
# Iteration 88: time=0.02, ELBO=-448317.67, deltaELBO=13.621 (0.00067703%), Factors=5
# Iteration 89: time=0.02, ELBO=-448304.23, deltaELBO=13.432 (0.00066766%), Factors=5
# Iteration 90: time=0.02, ELBO=-448291.00, deltaELBO=13.235 (0.00065786%), Factors=5
# Iteration 91: time=0.02, ELBO=-448277.97, deltaELBO=13.032 (0.00064777%), Factors=5
# Iteration 92: time=0.02, ELBO=-448265.14, deltaELBO=12.826 (0.00063754%), Factors=5
# Iteration 93: time=0.03, ELBO=-448252.52, deltaELBO=12.621 (0.00062733%), Factors=5
# Iteration 94: time=0.04, ELBO=-448240.10, deltaELBO=12.419 (0.00061728%), Factors=5
# Iteration 95: time=0.04, ELBO=-448227.88, deltaELBO=12.222 (0.00060749%), Factors=5
# Iteration 96: time=0.03, ELBO=-448215.85, deltaELBO=12.032 (0.00059807%), Factors=5
# Iteration 97: time=0.02, ELBO=-448204.00, deltaELBO=11.852 (0.00058909%), Factors=5
# Iteration 98: time=0.02, ELBO=-448192.31, deltaELBO=11.681 (0.00058060%), Factors=5
# Iteration 99: time=0.02, ELBO=-448180.79, deltaELBO=11.521 (0.00057263%), Factors=5
#
#
# #######################
# ## Training finished ##
# #######################
#
#
# Warning: Output file template_test.hdf5 already exists, it will be replaced
# Saving model in template_test.hdf5...
# <KeysViewHDF5 ['data', 'expectations', 'features', 'groups', 'intercepts', 'model_options', 'samples', 'training_opts', 'training_stats', 'variance_explained', 'views']>
